# %%
import seaborn as sns
import pandas as pd
import numpy as np

n = 50
summa = 0
f = open('1.txt')
arr = []
for i in range(n):
    x = float(f.readline()[:-1])
    summa += x
    arr.append(x)
average = round(summa/n, 2)
f.close()

# %%
b = []
s = 0
for i in range(n):
    x = (arr[i] - average)**2
    b.append(x)
    s += x
    
sigma = (s/(n-1))**0.5
delta = round((2.01 * sigma) / (50)**0.5, 2)
print(average, delta)

tmin = min(arr)
tmax = max(arr)
print(tmin, tmax)
tdelta = round((tmax - tmin) / 5000, 5)

T = []
T.append(tmin)
for i in range(1, 5000):
    T.append(round(tdelta + T[i - 1], 5))
# Out:
# 10.06 0.04
# 9.77 10.36

# %%
from math import pi, exp
ro = []

for i in range(len(T)):
    x = (1/(sigma * (2 * pi) ** 0.5)) * exp(-((T[i] - average) ** 2) / (2 * sigma ** 2))  
    ro.append(round(x, 3))

rom = 1 / (sigma * (2 * pi) ** 0.5)


for i in range(len(T)):
    ro[i] = ro[i]

# %%
sns.barplot(x=T, y=ro)
# Out:
# /Users/antongyrdymov/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/antongyrdymov/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/antongyrdymov/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(x=T, bins=50, density=True)
grid = np.linspace(0, 11, 11)
plt.plot(grid, color='red', label='Истинная плотность')

plt.legend()

plt.show()

# %%
sns_plot = sns.distplot(arr, bins=10, axlabel="Time")
fig = sns_plot.get_figure()
# Out:
# /var/folders/mn/896tmd911dj762f38chp4hcm0000gn/T/ipykernel_13747/1375926643.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_plot = sns.distplot(arr, bins=10, axlabel="Time")
# /Users/antongyrdymov/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.plot(T, ro)
plt.hist(arr, density=True, bins=7, label='arr')
plt.legend(['Функция Гаусса', 'Гистограмма'])

# %%
plt.hist(arr, bins=7)
# Out:
# (array([ 3.,  4., 15., 11.,  8.,  6.,  3.]),
#  array([ 9.77      ,  9.85428571,  9.93857143, 10.02285714, 10.10714286,
#         10.19142857, 10.27571429, 10.36      ]),
#  <BarContainer object of 7 artists>)
